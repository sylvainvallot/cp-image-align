# %%
from imageAlign import SetAlignmentPoints, AlignImages

bg_path = './data/In718-5min_EBSD_mask.tif'
bg_points = './data/In718-5min_EBSD_mask.points'

layer_path = './data/E_In718-5min.tif'
layer_points = './data/E_In718-5min.points'

background = SetAlignmentPoints(bg_path, points_file=bg_points)
layer = SetAlignmentPoints(layer_path, points_file=layer_points)

folder_name = 'output'

align_image = AlignImages(background, layer, 'layer')
align_image.align()
align_image.plot(stacked=False)
# align_image.export(folder_name)
